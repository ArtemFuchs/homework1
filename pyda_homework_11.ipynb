# %% [markdown]
# **Домашнее задание**

# %%
import pandas as pd

# %% [markdown]
# **Задание 1**
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# 	- оценка 2 и меньше - низкий рейтинг
# 	- оценка 4 и меньше - средний рейтинг
# 	- оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
def class_(param):
    if param <= 2.0:
        class_ = 'low'
    elif 2.0 < param <= 4.0:
        class_ = 'medium'
    elif 4.5 <= param <= 5.0:
        class_ = 'high'
    return class_

# %%
ratings['class'] = ratings['rating'].apply(class_)
ratings.head()
# Out:
#    userId  movieId  rating  timestamp   class
# 0       1        1     4.0  964982703  medium
# 1       1        3     4.0  964981247  medium
# 2       1        6     4.0  964982224  medium
# 3       1       47     5.0  964983815    high
# 4       1       50     5.0  964982931    high

# %% [markdown]
# **Задание 2**
#
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце 'region' пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим 'undefined'.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
#     'Центр': ['москва', 'тула', 'ярославль'],
#
#     'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
#     'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
#
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
keywords = pd.read_table('keywords.csv', sep = ',', encoding = 'utf-8')
keywords.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_data = {

'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']

}

# %%
def geo_class(keyword):
    for key, value in geo_data.items():
        for city in value:
            if city in keyword:
                region = str(key)
                break
            else:
                region = 'undefined'
                
    return region

# %%
keywords['region'] = keywords['keyword'].apply(geo_class)

# %%
keywords[keywords['region'] != 'undefined']
# Out:
#                                                  keyword   shows  \
# 1063                                 фарпост владивосток  176951
# 2175                                      дром хабаровск   98361
# 3206                                    дром владивосток   73084
# 3275                                  100 сп владивосток   76418
# 3687                                     авито хабаровск   63736
# 5858                                         владивосток   43038
# 6260                                   фарпост хабаровск   40962
# 8039                                 погода в хабаровске   33437
# 9084                                           хабаровск   29655
# 9293                                    100 сп хабаровск   29475
# 10261                              дром хабаровский край   27062
# 14637                     презент хабаровск свежий номер   20524
# 16474                                работа в хабаровске   18284
# 16544                             погода во владивостоке   18262
# 18148                                farpost владивосток   16725
# 68736  Дальний Восток
# 69360  Дальний Восток
# 69652  Дальний Восток
# 69716  Дальний Восток
# 71869  Дальний Восток
# 72019  Дальний Восток
# 72430  Дальний Восток
# 72766  Дальний Восток
# 78517  Дальний Восток
# 80269  Дальний Восток
# 81887  Дальний Восток
# 82474  Дальний Восток
# 88430  Дальний Восток
# 89445  Дальний Восток
# 89757  Дальний Восток
# 89937  Дальний Восток
# 90402  Дальний Восток
# 92442  Дальний Восток
# 92843  Дальний Восток
# 93872  Дальний Восток
# 95572  Дальний Восток
#
# [94 rows x 3 columns]

# %% [markdown]
# **Задание 3 (бонусное)**
#
# Есть мнение, что "раньше снимали настоящее кино, не то что сейчас". Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл ratings.csv из базы https://grouplens.org/datasets/movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# 1. В переменную years запишите список из всех годов с 1950 по 2010.
#
# 2. Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
# 	- для каждой строки пройдите по всем годам списка years
# 	- если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# 	- если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
#
# 3. Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец 'year'
#
# 4. Посчитайте средний рейтинг всех фильмов для каждого значения столбца 'year' и отсортируйте результат по убыванию рейтинга

# %%
years = []
for year in range(1950,2011):
    years.append(str(year))

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
movies = pd.read_csv('ml-latest-small/movies.csv')

# %%
joined = ratings.merge(movies, how='left', on='movieId')
joined.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres
# 0                             Drama
# 1  Animation|Children|Drama|Musical
# 2                          Thriller
# 3  Action|Adventure|Sci-Fi|Thriller
# 4                             Drama

# %%
def production_year(title):
    for year in years:
        if str(year) in title:
            year = str(year)
            break
        else:
            year = '1900'
    return year

# %%
joined['year'] = joined['title'].apply(production_year)
joined_filtered = joined.filter(items = ['rating', 'year'])
joined_filtered.groupby('year').mean()[['rating']].sort_values('rating', ascending=False).reset_index().head()
# Out:
#    year    rating
# 0  1957  4.014241
# 1  1972  4.011136
# 2  1952  4.000000
# 3  1954  3.994220
# 4  1951  3.983539
