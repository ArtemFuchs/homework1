# %% [markdown]
# **Задание 1**
#
# 1. Используйте файл с оценками фильмов ml-latest-small/ratings.csv. Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок. Под временем жизни понимается разница между максимальным и минимальным значением столбца timestamp для данного значения userId.

# %%
import pandas as pd
from datetime import datetime

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
counted = ratings.groupby('userId')['timestamp'].count()
diff = ratings.groupby('userId').max()[['timestamp']] - ratings.groupby('userId').min()[['timestamp']]
diff = diff[ counted > 100 ]
diff['lifetime'] = diff['timestamp'].astype('timedelta64[m]')
diff.head(200)
# Out:
#         timestamp                     lifetime
# userId
# 4          203560            141 days 08:40:00
# 8           85187             59 days 03:47:00
# 15      471393496 -99652 days +15:06:52.580896
# 17           8053              5 days 14:13:00
# 19           5282              3 days 16:02:00
# 21        1365432            948 days 05:12:00
# 22          91491             63 days 12:51:00
# 23       18342129          12737 days 14:09:00
# 26       20267261          14074 days 11:41:00
# 30      115852276          80452 days 23:16:00
# 33        4332211           3008 days 11:31:00
# 34           2835              1 days 23:15:00
# 36        5949290           4131 days 10:50:00
# 38       59971665          41646 days 23:45:00
# 41       15930495          11062 days 20:15:00
# 43          13885              9 days 15:25:00
# 48      136315977          94663 days 20:57:00
# 56        8564120           5947 days 07:20:00
# 57           4323              3 days 00:03:00
# ...

# %% [markdown]
# **Задание  2**
# 2. Дана статистика услуг перевозок клиентов компании по типам (см. файл с кодом занятия). Необходимо сформировать две таблицы:
#     - таблицу с тремя типами выручки для каждого client_id без указания адреса клиента
#     - аналогичную таблицу по типам выручки с указанием адреса клиента. Обратите внимание, что в процессе объединения таблиц данные не должны теряться.

# %% [markdown]
# ### К домашнему заданию, задача 2
# Дана статистика услуг перевозок клиентов компании по типам:
# - rzd - железнодорожные перевозки
# - auto - автомобильные перевозки
# - air - воздушные перевозки
# - client_base - адреса клиентов

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
joined_earnings = rzd.merge(auto, how='outer')
joined_earnings = joined_earnings.merge(air, how='outer')
joined_earnings
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           NaN          NaN
# 1        112       2810.0           NaN          NaN
# 2        113      10283.0       57483.0          NaN
# 3        114       5774.0          83.0          NaN
# 4        115        981.0         912.0         81.0
# 5        116          NaN        4834.0          4.0
# 6        117          NaN          98.0         13.0
# 7        118          NaN           NaN        173.0

# %%
joined_earnings = client_base.merge(joined_earnings, how='left')
joined_earnings
# Out:
#    client_id          address  rzd_revenue  auto_revenue  air_revenue
# 0        111  Комсомольская 4       1093.0           NaN          NaN
# 1        112   Энтузиастов 8а       2810.0           NaN          NaN
# 2        113  Левобережная 1а      10283.0       57483.0          NaN
# 3        114          Мира 14       5774.0          83.0          NaN
# 4        115        ЗЖБИиДК 1        981.0         912.0         81.0
# 5        116    Строителей 18          NaN        4834.0          4.0
# 6        117  Панфиловская 33          NaN          98.0         13.0
# 7        118     Мастеркова 4          NaN           NaN        173.0

# %% [markdown]
# **Задание 3**
# 3. В задаче сквозной аналитики вам предоставили данные по местоположению пользователей. Т. е. для каждого user_id известна последовательность координат (широта/долгота), когда они требовались приложению для полноценной работы. Как бы вы добавили эти сведения в таблицу визитов и покупок? Для составления ответа можно использовать вопросы:
#     - У каждого пользователя известен набор координат. А для связывания с визитом или фактом покупки скорее всего потребуется одно-два числа. Как их получить?
#     - Наборы координат одного и того же пользователя могут быть значительно удалены друг от друга. Как это отразится на вопросе расчетах пункта 1?
#     - Какие дополнительные признаки можно получить из координат? Ведь это просто числа, которые сами по себе мало что дают.

# %% [markdown]
# Для каждого user_id составил бы таблицу со временем фиксирования координат приложением и полученными в это время координатами. Для связи с визитом определил бы координаты магазина и искал аналогичные в таблице с координатами пользователя. Для факта покупки определил бы время покупки и искал такое же время, либо близкое, при этом координаты пользователя должны совпадать/примерно совпадать (хотя имеется вероятность того, что пользователь просто проходил мимо магазина) с координатами магазина. Из координат можно установить расстояние, преодолеваемое пользователем; частоту посещений магазина, предпочтения в выборе магазина, если их несколько; возможно определить вид транспорта, которым пользуется пользователь
